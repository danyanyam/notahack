# %%
import IPython.display as ipd

PATH_MAN = 'ffmpeg_output_1.wav'
ipd.Audio(PATH_MAN)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install vosk
# Out:
# Requirement already satisfied: vosk in /usr/local/lib/python3.6/dist-packages (0.3.7)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from vosk import Model, KaldiRecognizer
import sys
import json
import os
import wave 



def load_voice(PATH):
    name = 'drive/My Drive/vosk-model-small-ru-0.4/vosk-model-small-ru-0.4' # путь к весам
    wf = wave.open(PATH, "rb")

    if wf.getnchannels() != 1 or wf.getsampwidth() != 2 or wf.getcomptype() != "NONE":
        print ("Audio file must be WAV format mono PCM.")
        exit (1)

    model = Model(name)
    rec = KaldiRecognizer(model, wf.getframerate())

    while True:
        data = wf.readframes(4000)
        if len(data) == 0:
            break
        if rec.AcceptWaveform(data):
            pass
        
    return json.loads(rec.FinalResult())['text']


PATH = 'drive/My Drive/ssh/test wavs/тест1.wav'
PATH = 'ffmpeg_output_1.wav' # путь к файлу
load_voice(PATH)
# Out:
# 'сможете присутствует пацаны вся но вот в двадцать четыре минут через тридцать минут кто она бизнес и продукт технолог гиза тред аналогии разработка проекта'

# %%
import os
os.listdir('drive/My Drive/vosk-model-small-ru-0.4/vosk-model-small-ru-0.4')
# Out:
# ['README', 'conf', 'am', 'graph', 'ivector']

# %%
import os

PATH_MAIN = 'drive/My Drive/ssh/test wavs'
wav_sounds = sorted([i for i in os.listdir(PATH_MAIN) if len(i.split('.wav')) != 1])

previously_said = []
for wav in wav_sounds:
    previously_said.append(load_voice(wav).capitalize() + '.')

print(' '.join(previously_said))
# Out:
# Привет всем меня зовут ты не и я живу в городе москва. Всем привет с вами даниил очко.
